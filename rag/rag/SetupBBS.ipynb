# %% [markdown]
# # Setup de l'environnement

# %%
# Create and activate the environment
# !conda create --name bbs python=3.12 anaconda ipykernel -y -q

# %%
# Install compile toolkit
# !conda install -c conda-forge gcc=12 -y -q

# %%
# Install CUDA toolkit and cuDNN
# !conda install -c anaconda cudatoolkit cudnn -y -q

# %%
# Install PyTorch with CUDA support
# !conda install -c pytorch -c nvidia pytorch torchvision torchaudio pytorch-cuda -y -q

# %%
# Install the required libraries
# !conda install -c conda-forge -c nvidia transformers tensorflow ipywidgets scikit-learn tiktoken -y -q

# %%
# !conda install -c conda-forge langchain langchain-community langchain-nomic langchain-openai "nomic[local]" langgraph -y -q

# %%
# !python -m pip install langchain-ollama "langgraph-cli[inmem]"
# Out:
# ...
#   Using cached onnxruntime-1.20.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# ...
# Using cached onnxruntime-1.20.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
# ...

# %%
# !python -m pip install python-dotenv sentence_transformers "pypdf[full]" faiss-gpu-cu12 chromadb onnxruntime-gpu

# %%
# !python -m pip uninstall onnxruntime -y
# Out:
# Found existing installation: onnxruntime 1.20.1
# Uninstalling onnxruntime-1.20.1:
#   Successfully uninstalled onnxruntime-1.20.1

# %% [markdown]
# # Comment activer ce setup de mise en route
#
# Installer JupyterLab dans l'environnement de base:
# `conda install -c conda-forge jupyterlab -y -q`
#
# Lancer cet environnement de développement:
# `jupyter lab --no-browser --port 8887`

# %% [markdown]
# # Configuration finale

# %%
# Add the conda environment to the user kernels
# !python -m ipykernel install --user --name=bbs

# %% [markdown]
# ## Maintenant, il faut changer le Kernel de ce Notebook vers le nouveau kernel que nous venons de créer
#
# ### Choisi le menu des Kernels
# ![image.png](attachment:44014dfe-4f3e-4711-b1cc-d653c12dabeb.png)
#
# ### Selectionnez le nouveau Kernel
# ![image.png](attachment:9673f765-2c4b-4441-8ef7-c21f96e22f09.png)

# %% [markdown]
# # Langraph Studio Setup

# %%
# !python -m pip install -U "langgraph-cli[inmem]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.9 MB/s eta 0:00:008.2 MB/s eta 0:00:01
# ...
#   Attempting uninstall: structlog
#     Found existing installation: structlog 24.4.0
#     Uninstalling structlog-24.4.0:
#       Successfully uninstalled structlog-24.4.0
#   Attempting uninstall: langgraph-cli
#     Found existing installation: langgraph-cli 0.1.65
#     Uninstalling langgraph-cli-0.1.65:
#       Successfully uninstalled langgraph-cli-0.1.65
#   Attempting uninstall: jsonschema-rs
#     Found existing installation: jsonschema_rs 0.25.1
#     Uninstalling jsonschema_rs-0.25.1:
#       Successfully uninstalled jsonschema_rs-0.25.1
#   Attempting uninstall: langgraph-sdk
#     Found existing installation: langgraph-sdk 0.1.48
#     Uninstalling langgraph-sdk-0.1.48:
#       Successfully uninstalled langgraph-sdk-0.1.48
#   Attempting uninstall: langgraph-checkpoint
#     Found existing installation: langgraph-checkpoint 2.0.9
# ...

# %%
# !which $CONDA_PREFIX/bin/langgraph dev
# Out:
# /home/martino/miniconda3/envs/jupyterlabs/bin/langgraph

# %% [markdown]
# ## Pour lancer le studio

# %%
# !rm -rf .langgraph_api/
# !$CONDA_PREFIX/bin/langgraph dev --no-browser
# Out:
# INFO:langgraph_api.cli:
#
#         Welcome to
#
# ╦  ┌─┐┌┐┌┌─┐╔═╗┬─┐┌─┐┌─┐┬ ┬
# ║  ├─┤││││ ┬║ ╦├┬┘├─┤├─┘├─┤
# ╩═╝┴ ┴┘└┘└─┘╚═╝┴└─┴ ┴┴  ┴ ┴
#
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
#
# This in-memory server is designed for development and testing.
# For production use, please use LangGraph Cloud.
#
#
# 2025-03-03T10:41:50.315671Z [info     ] Will watch for changes in these directories: ['/home/martino/JupyterProjects'] [uvicorn.error] api_variant=local_dev
# 2025-03-03T10:41:50.315850Z [info     ] Uvicorn running on http://127.0.0.1:2024 (Press CTRL+C to quit) [uvicorn.error] api_variant=local_dev color_message=Uvicorn running on %s://%s:%d (Press CTRL+C to quit)
# 2025-03-03T10:41:50.316052Z [info     ] Started reloader process [2469] using WatchFiles [uvicorn.error] api_variant=local_dev color_message=Started reloader process [2469] using WatchFiles
# ...
